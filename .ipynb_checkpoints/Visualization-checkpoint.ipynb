# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## The `.plot() ` Method

# %%
bb = data.DataReader(name = "AAPL", data_source = "yahoo", start = "2007-07-01", end = "2008-12-31")
bb.head(3)
data.DataReader
# Out:
# <function pandas_datareader.data.DataReader(name, data_source=None, start=None, end=None, retry_count=3, pause=0.1, session=None, api_key=None)>

# %%
bb[["High", "Low"]].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Modifying Aesthetics

# %%
bb = data.DataReader(name = "AAPL", data_source = "yahoo", start = "2007-07-01", end = "2008-12-31")
bb.head(3)
# Out:
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 2007-07-02  4.360357  4.260714  4.323214  4.330714   994862400   3.713004
# 2007-07-03  4.550000  4.339286  4.357143  4.541786  1162481600   3.893968
# 2007-07-05  4.748929  4.596071  4.600000  4.741071  1453051600   4.064829

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("dark_background")
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.style.use("ggplot")
bb.plot(y = "Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Bar Charts

# %%
google = data.DataReader(name = "GOOG", data_source = "yahoo", start = "2004-01-01", end = "2016-12-31")
google.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0  54.495735

# %%
def rank_performance(stock_price):
    if stock_price <= 200:
        return "Poor"
    elif stock_price > 200 and stock_price <= 500:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
plt.style.use("ggplot")
google["Close"].apply(rank_performance).value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pie Charts

# %%
apple = data.DataReader(name = "AAPL", data_source = "yahoo", start = "2012-01-01", end = "2016-12-31")
apple.head(3)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2012-01-03  14.732143  14.607143  14.621429  14.686786  302220800.0  12.591934
# 2012-01-04  14.810000  14.617143  14.642857  14.765714  260022000.0  12.659610
# 2012-01-05  14.948214  14.738214  14.819643  14.929643  271269600.0  12.800157

# %%
apple["Close"].mean()
# Out:
# 23.340429820771817

# %%
def rank_performance(stock_price):
    if stock_price >= 92.63809405940599:
        return "Above Average"
    else:
        return "Below Average"

# %%
plt.style.use("ggplot")
apple["Close"].apply(rank_performance).value_counts().plot(kind = "pie", legend = True)
# Out:
# <AxesSubplot:ylabel='Close'>

# %% [markdown]
# ## Histograms

# %%
google = data.DataReader(name = "GOOG", data_source = "yahoo", start = "2004-01-01", end = "2016-12-31")
google.head(3)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813290  49.982655  44871361.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942874.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342897.0  54.495735

# %%
def custom_round(stock_price):
    return int(stock_price / 100.0) * 100

# %%
google["High"].apply(custom_round).value_counts().sort_index()
# Out:
# 0       159
# 100     414
# 200    1132
# 300     447
# 400     157
# 500     415
# 600     106
# 700     273
# 800      12
# Name: High, dtype: int64

# %%
google["High"].apply(custom_round).nunique()
# Out:
# 9

# %%
google["High"].apply(custom_round).plot(kind = "hist", bins = 9)
# Out:
# <AxesSubplot:ylabel='Frequency'>
